# %%
import sqlite3
import pandas as pd

# %%
# accès à la table departement pour afficher son contenu
connexion = sqlite3.connect('Database.db')
cursor = connexion.cursor()

query =  '''SELECT 
        offres.intitule,
        offres.poste,
        offres.profil,
        offres.description_offre,
        offres.date_creation,
        offres.salaire_min_annuel,
        offres.salaire_max_annuel,
        offres.salaire_annuel_mean,
        offres.qualification_libelle,
        offres.experience,
        offres.type_contrat,
        offres.secteur_activite,
        offres.id_ville,
        offres.id_entreprise,
        d_ville.id,
        d_ville.ville,
        d_ville.latitude,
        d_ville.longitude,
        d_ville.code_postal,
        d_ville.departement,
        d_entreprise.id,
        d_entreprise.entreprise_nom,
        d_entreprise.entreprise_description,
        h_departement.departement,
        h_departement.departement_nom,
        h_departement.region
        
        FROM offres
        INNER JOIN d_ville ON offres.id_ville = d_ville.id
        INNER JOIN d_entreprise ON offres.id_entreprise = d_entreprise.id
        INNER JOIN h_departement ON d_ville.departement = h_departement.departement;
        '''

df = pd.read_sql_query(query, connexion)

connexion.close()

# %%
df
# Out:
#                                               intitule           poste  \
# 0                       Senior Data Engineer F/H (H/F)   data engineer
# 1                                    Data Engineer H/F   data engineer
# 2             Analytics Engineer F/H - Marketing (H/F)   data engineer
# 3                                  DATA ENGINEER - H/F   data engineer
# 4                                  DATA ENGINEER - H/F   data engineer
# ..                                                 ...             ...
# 266      PhD / Jeune Docteur - Data scientist & IA F/H  data scientist
# 267          Analyste développeur - data scientist F/H  data scientist
# 268  Data scientist / Chargé(e) d'études sur la pet...  data scientist
# 269  Expert en sciences des données spécialisé en I...  data scientist
# 270  Data scientist / Chargé(e) d'études sur la pet...  data scientist
#
#                                                 profil  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 266  CE QUE NOUS RECHERCHONS\r\nVous êtes titulaire...
# 267  Diplômé d’un Bac+5 scientifique, vous possédez...
# 268  Etes-vous notre prochain(e) Data scientist ?\r...
# 269  Expérience :\r\nAu moins 5 ans d'expérience en...
# 270   \r\nTitulaire d'un bac+5 en statistiques et/o...
#
#                                      description_offre date_creation  \
# 0    Le saviez-vous ?\r\n\r\nNous rejoindre, c'est ...    29/12/2023
# 1    Rejoindre le Groupe IRCEM, c'est participer à ...    29/12/2023
# 2    Descriptif du poste:\r\n\r\nRôle : L Analytics...    29/12/2023
# 3    Description :\r\n\r\n\r\nvous rejoindrez une é...    28/12/2023
# 4    Description :\r\n\r\n\r\nvous rejoindrez une é...    28/12/2023
# ..                                                 ...           ...
# 266  LE PROJET Nous recherchons un(e) Chef(fe) de p...    19/12/2023
# 267  L’arrivée à maturité de solutions informatique...    06/12/2023
# 268  Concrètement votre futur quotidien ?\r\nVous p...    28/12/2023
# 269  Mission :\r\nEn tant que Data scientist spécia...    18/12/2023
# 270   \r\nConcrètement votre futur quotidien ?\r\nV...    19/12/2023
#
#     salaire_min_annuel salaire_max_annuel salaire_annuel_mean  \
# 0                 None               None                None
# 1                 None               None                None
# 2                 None               None                None
# 3              45000.0            55000.0             50000.0
# 4              45000.0            55000.0             50000.0
# ..                 ...                ...                 ...
# 266               None               None                None
# 267               None               None                None
# 268               None               None                None
# 269               None               None                None
# 270               None               None                None
#
#                 qualification_libelle experience  ...   latitude longitude  \
# 0                                None        oui  ...  49.687882  1.395968
# 1                                None        oui  ...  50.688369  3.181903
# 2                               Cadre        oui  ...  48.742795  2.394977
# 3                                None        oui  ...  47.873504  1.917316
# 4                                None        oui  ...  43.536112  5.398630
# ..                                ...        ...  ...        ...       ...
# 266            Cadre du secteur privé        non  ...  43.596038  1.432095
# 267            Cadre du secteur privé        non  ...  48.571265  7.767760
# 268            Cadre du secteur privé        oui  ...  48.829262  2.326537
# 269  Cadre du secteur public / Armées        oui  ...  48.840072  2.292837
# 270            Cadre du secteur privé        non  ...  48.829262  2.326537
#
#      code_postal       departement   id  \
# 0        76270.0    seine-maritime    2
# 1        59100.0              nord    3
# 2        94310.0      val-de-marne    4
# 3        45100.0            loiret    6
# 4        13080.0  bouches-du-rhône    6
# ..           ...               ...  ...
# 266      31100.0     haute-garonne  226
# 267      67000.0          bas-rhin  228
# 268      75014.0             paris  229
# 269      75015.0             paris  230
# 270      75014.0             paris  231
#
#                                     entreprise_nom  \
# 0                                             None
# 1                                            IRCEM
# 2                                              CPF
# 3                                  DSI Pôle Emploi
# 4                                  DSI Pôle Emploi
# ..                                             ...
# 266                                      CAPGEMINI
# 267                EURO-INFORMATION DEVELOPPEMENTS
# 268                                           CNAF
# 269  DIRECTION DU NUMÉRIQUE DES MINISTÈRES SOCIAUX
# 270                                           CNAF
#
#                                 entreprise_description       departement  \
# 0    Nous rejoindre, c'est rejoindre l'un des leade...    seine-maritime
# 1                                                 None              nord
# 2    Depuis 2002, Amorino émerveille les gourmands ...      val-de-marne
# 3                                                 None            loiret
# 4                                                 None  bouches-du-rhône
# ..                                                 ...               ...
# 266  CAPGEMINI Capgemini, qu'est-ce que cela évoque...     haute-garonne
# 267  Euro-Information, filiale technologique de Cré...          bas-rhin
# 268  Vous souhaitez rejoindre une équipe expériment...             paris
# 269  Vous souhaitez intégrer une Direction numériqu...             paris
# 270  Vous souhaitez rejoindre une équipe expériment...             paris
#
#       departement_nom                      region
# 0      seine-maritime                   normandie
# 1                nord             hauts-de-france
# 2        val-de-marne               île-de-france
# 3              loiret         centre-val de loire
# 4    bouches-du-rhône  provence-alpes-côte d'azur
# ..                ...                         ...
# 266     haute-garonne                   occitanie
# 267          bas-rhin                   grand est
# 268             paris               île-de-france
# 269             paris               île-de-france
# 270             paris               île-de-france
#
# [271 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   poste                   271 non-null    object
#  1   intitule                271 non-null    object
#  2   description_offre       271 non-null    object
#  3   profil                  106 non-null    object
#  4   date_creation           271 non-null    object
#  5   salaire_min_annuel      63 non-null     object
#  6   salaire_max_annuel      57 non-null     object
#  7   salaire_annuel_mean     63 non-null     object
#  8   qualification_libelle   182 non-null    object
#  9   experience              271 non-null    object
#  10  type_contrat            271 non-null    object
#  11  secteur_activite        214 non-null    object
#  12  ville                   271 non-null    object
#  13  latitude                271 non-null    float64
#  14  longitude               271 non-null    float64
#  15  code_postal             271 non-null    object
#  16  ville_departement       271 non-null    object
#  17  entreprise_nom          225 non-null    object
#  18  entreprise_description  199 non-null    object
#  19  departement             271 non-null    object
#  20  departement_nom         0 non-null      object
#  21  region                  271 non-null    object
# dtypes: float64(2), object(20)
# memory usage: 46.7+ KB
